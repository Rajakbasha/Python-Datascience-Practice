# %%
# Decisions in python (if_else statements)
# check if a person is eligible for a job at any companies 
age=int(input("enter your age:-"))
graduation_year=int(input("enter your graduation year:"))
if age>=21 and graduation_year<2023:
     ("Eligibility check :-please upload your experience certificates.")
else:
 print("sorry ,you do not meet the age requirements currently")
# Out:
# enter your age:- 67
# enter your graduation year: 2023
# sorry ,you do not meet the age requirements currently

# %%
# simple Pass and Fail logic 
marks=float(input("\n enter your percentage:"))
if marks>=40:
         print("Result: PASS")
else:
       print("Result: FAIL")
# Out:
#  enter your percentage: 90
# Result: PASS
