# %%
# Introduction To Python

# %%
""" Let's is  have a look at python as a language and what features does it bring to be among the top 3 coding languages in the world """
# Out:
# " Let's is  have a look at python as a language and what features does it bring to be among the top 3 coding languages in the world "

# %%
# 1 .unlike other langueges Python program works on an interpreter so to run a code all you have to do is type it out

# %%
print("WELCOME TO LEARNER Rajak basha you have achieve  you a have day 2  ")
# Out:
# WELCOME TO LEARNER Rajak basha you have achieve  you a have day 2

# %%
# Python language runs line by line so incase you want to update a piece of code all you have to do is update the line let,s see how 
# Imaginary giraffe

print("O  ")
print("|  ")
print("|__")
print("||||")
print("||||")
# Out:
# O
# |
# |__
# ||||
# ||||

# %%
 # lets add another print statement 
print("$"*3)
# Out:
# $$$

# %%
print(" Rajak " * 5)
# Out:
#  Rajak  Rajak  Rajak  Rajak  Rajak

# %%
var1="Mike"
print(var1)
# Out:
# Mike

# %%
var2=6
print(var2)
# Out:
# 6

# %%
# NOW we have learn how to store a variable in python lets try getting input from user and storing it in Python 
# To get a input from user we would use the ' input ' function 
number=input("What is your favourite number?")
print("my favourite number is :",number)
# Out:
# What is your favourite number? 5
# my favourite number is : 5

# %%
# let's try taking adding a string to the answer received 
name=input("Enter your name : ")
print("Welcome",name)
# Out:
# Enter your name :  Rajak basha
# Welcome Rajak basha

# %%
age=input("Enter your age : ")
print("you are ",age*12," years  old")
# Out:
# Enter your age :  24
# you are  242424242424242424242424  years  old

# %%
age=input("Enter your age ")
age=int(age)
print("Your are ",age*12,"months old ")
# Out:
# Enter your age  24
# Your are  288 months old

# %%
# changing the of variable type is called typecasting

# %%
#  How to find the Data Type for a variablein Python 
""" Here in the below piece of code you can see that we have assigned each variable with a particular value and use the type method we can check the datatype of the variable
"""
# Out:
# ' Here in the below piece of code you can see that we have assigned each variable with a particular value and use the type method we can check the datatype of the variable\n'

# %%
integer_num=1
floating_num=1.3
string="Rajak Basha"
boolean=True
print(type(integer_num))
print(type(floating_num))
print(type(string))
print(type(boolean))
print("Type casting in pyhton")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# Type casting in pyhton

# %%
# now let us try taking an 
a=1
print(a)
print(bool(a))
print(float(a))
print(str(a))
# Out:
# 1
# True
# 1.0
# 1

# %%
#ARITHMATIC Operator 
a=6
b=7
print("Addition=",a+b)
print("substraction=",a-b)
print("Multiplication =",a*b)
print("Division =",a/b)
print('Floor Division =',a//b)
print("Modulus or remainder =",a%b)
print("Exponential=",a**b)
""" NOW i recall that the mathematical operators follow a precedence rule called PEDMAS RULE 
# P is parenthesis 
# E is exponent 
# D  is division 
# M multiplication 
# A addition 
# S  substraction   """
# Out:
# Addition= 13
# substraction= -1
# Multiplication = 42
# Division = 0.8571428571428571
# Floor Division = 0
# Modulus or remainder = 6
# Exponential= 279936
# ' NOW i recall that the mathematical operators follow a precedence rule called PEDMAS RULE \n#  P is parenthesis \n# E is exponent \n# D  is division \n# M multiplication \n# A addition \n# S  substraction   '

# %%
print((4*5)-9+6/7)
# Out:
# 11.857142857142858
