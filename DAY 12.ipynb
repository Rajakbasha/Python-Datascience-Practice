# %%
## FUNCTIONS 
def greet (name):
  print("Good evening ",name)
def double_it(num):
  return num*2
def square_area(side):
 print("Area is:",side*side)
def add_three(a,b,c):
 return a+b+c
def even_odd(n):
 print(n,"is even")
def find_age(2000):
  age=(2026-birth_year)
print("your age is :",age)
def get_interest(p,t,r):
 interest=(p*t*r)/100
return intrest
def km_to_miles(km):
 return km*0.62
def find_max(a,b):
  if a>b:
     print(a,"is bigger")
  else:
     print(b,"is bigger")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 14
#      12 def find_age(birth_year):
#      13   age=(2026-birth_year)
# ---> 14 print("your age is :",age)
#      15 def get_interest(p,t,r):
#      16  interest=(p*t*r)/100
#
# NameError: name 'age' is not defined
