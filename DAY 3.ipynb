# %%
# 1. Booleans (True Or False )
# A Boolean is data  type that can be one of two things .True Or False  
# We Create Booleans using Comparison 
# [i]     == singke equals checks assighn a variable 
# [ii]    != Not equal to 
# [iii]   > greater than 
# [iv]    < less than 
#[ v]     >= greater than equal to 
# [vi]    <=less than equal to

# %%
is_rajak=True
print(10>5) 
print(100==9)
# Out:
# True
# False

# %%
is_rajak=False
print(100==1)
print(100==100)
# Out:
# False
# True

# %%
# If/ Else Statement 
# this is how we control the flow of the program 
# python uses indetation 4 spaces  belongs inside the if statment

# %%
Age=int(input("Enter your age:-"))
if Age>=18:
    print("You are an Adult")
else:
    print("you are a minor")
# Out:
# Enter your age:- 6
# you are a minor

# %%
age=int(input("Enter your age :"))
if age<=18:
    print(" yes you have minor")
else:
    print ("yes you have adult")
# Out:
# Enter your age : 9
#  yes you have minor

# %%
""" We should look at string as a banner where multiple characters are linked together 
    The string data is an immutable 
    it cannot be modified"""
# Out:
# ' We should look at string as a banner where multiple characters are linked together \n    The string data is an immutable \n    it cannot be modified'

# %%
# Whenever we are assighing a char or string we use " which represents a character 
c="z"
d="Rajak"
e='basha'
# it can be use "" double quotes instead of ' single quotes for strigs 
print(c)
print(d,e)
# Out:
# z
# Rajak basha

# %%
# Now it can we want to include word with single quote such as "didn't", "i'ii" ...we might end up with a error

# %%
print('I didn't know that')
# it is syntaxerror
# Out:
#   Cell In[8], line 1
#     print('I didn't know that')
#                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('I didn't know that)
# invalid syntax
# Out:
#   Cell In[10], line 1
#     print('I didn't know that)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Now we solve this we can use an escape charecter like 
print('I didn\'t know that')
# Out:
# I didn't know that

# %%
# we can use "" double quotes 
print("I did't know that")
# Out:
# I did't know that

# %%
# now to solve this we can use an escape charecter which we saw earlier can also be used for other stuff like addinn new line 
print("Hi Rajak \n\n How are you ? ")
# Out:
# Hi Rajak
#
#  How are you ?

# %%
# now apart of adding new line to string we can use also add another to pre-existing string,
# let's see how 
## string concatenation 
# 1. let's try building a system that could ask for flavour ,and the type of deesert user wants

# %%
flavour=input("what flavour would you like ")
dessert_type=input("what type of desert would you like ")
print("You have ordered ", flavour +"-"+dessert_type)
# Out:
# what flavour would you like  vennela
# what type of desert would you like  ice cream
# You have ordered  vennela-ice cream

# %%
"""# string manipilation :-
## indexing in strings <br>
-forward indexing starts with zero 
- reverse indexing starts with the last charecter as -1 in a python string 
-strings are immutable which, means they cannot be changed once created 
-strings  can be modified by slicing a part of it and concatinating with another """
# Out:
# '# string manipilation \n## indexing in strings <br>\n-forward indexing starts with zero \n- reverse indexing starts with the last charecter as -1 in a python string \n-strings are immutable which, means they cannot be changed once created \n-strings  can be modified by slicing a part of it and concatinating with another '

# %%
#Len() function 
string="i have not failed. i've just found 10,000 ways that won't work. _ THOMAS A.EDISON "
print(len(string))
# Out:
# 82

# %%
# Accesing first Charecter 
string[-82]
# Out:
# 'i'

# %%
string[-1]
# Out:
# ' '

# %%
string[2]
# Out:
# 'h'

# %%
# trying to change the charecter at index 2 
string[2]='R'
# YOU CAN'T CHANGE A CHARACTER AT AN INDEX "R" THIS IS IMMUTABLE 
# STR OBJECT DOES NOT SUPPORT IN PYTHON STRIGS ARE IMMUTABLE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # trying to change the charecter at index 2
# ----> 2 string[2]='R'
#
# TypeError: 'str' object does not support item assignment

# %%
""" # Changing the entire string or say changing the lebal of it 
string='I Have not failed. i've just found 10,000 ways that won't work.-Einstien'
print(string)
if this text contains a single quote (like 've or won't wrap the whole  string doube quotes(")"""
# Out:
# ' # Changing the entire string or say changing the lebal of it \nstring=\'I Have not failed. i\'ve just found 10,000 ways that won\'t work.-Einstien\'\nprint(string)\nif this text contains a single quote (like \'ve or won\'t wrap the whole  string doube quotes(")'

# %%
string="I Have not failed. i've just found 10,000 ways that won't work.-Einstien"
print(string)
# Out:
# I Have not failed. i've just found 10,000 ways that won't work.-Einstien

# %%
# string slicing works string[start:end:step]

# %%
"""Start : The index where you want to begin default is 0
 stop : the index where you want to end 
 step : how many charecters to jump  default is 1)"""
# Out:
# 'Start : The index where you want to begin default is 0\n stop : the index where you want to end \n step : how many charecters to jump  default is 1)'

# %%
sliced_statement =" i have not failed. i've just found 10,000 ways that won't work .Thomas A.Edition"
print(sliced_statement)
# Out:
#  i have not failed. i've just found 10,000 ways that won't work .Thomas A.Edition
