# %%
# python Lists   
skills=["Python", "SQL","Excell","Power Bi", "HTML"]
print("first skill:-",skills[0])
print("second skill:-",skills[1])
print("third skill:-",skills[2])
print("4th skill:-",skills[3])
# Out:
# first skill:- Python
# second skill:- SQL
# third skill:- Excell
# 4th skill:- Power Bi

# %%
# adding new skill 
skills.append("Machine Learning")
print(len(skills))
print("################")
skills.sort()
print("A-Z Orderd skills :",skills)
# Out:
# 8
# ################
# A-Z Orderd skills : ['Excell', 'HTML', 'Machine Learning', 'Machine Learning', 'Machine Learning', 'Power Bi', 'Python', 'SQL']

# %%
fruits=["APPLE","PINEAPPLE","COCONUT","ORANGE"]
print("first fruit",fruits[0])
print("second fruit",fruits[1])
fruits.append("BANANA")
print(len(fruits))
fruits.sort()
print(" A to Z Orderd :-",fruits)
# Out:
# first fruit APPLE
# second fruit PINEAPPLE
# 5
#  A to Z Orderd :- ['APPLE', 'BANANA', 'COCONUT', 'ORANGE', 'PINEAPPLE']
