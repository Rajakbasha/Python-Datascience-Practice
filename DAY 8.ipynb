# %%
#Understanding Data types 
name="rajak"
age=25
percentage=7.30
is_student=True
print(name)
print(age)
print(percentage)
print(is_student)
# Out:
# rajak
# 25
# 7.3
# True

# %%
# printing types to understanding 
print("name type",type(name))
print("age type",type(age))
print("percentage type:",type(percentage))
# Out:
# name type <class 'str'>
# age type <class 'int'>
# percentage type: <class 'float'>

# %%
# taking impuit  from user
print("\n---- user interaction ---")
user_name=input("enter your name:-")
user_city=input("enter your city:")
print("hello "+name+",you are from " + user_city)
# Out:
# ---- user interaction ---
# enter your name:- Rajak BASHA
# enter your city: KURNOOL
# hello rajak,you are from KURNOOL

# %%
## simple calculation with input 
num1=input("enter first number:-")
num2=input("enter your second number:-")
sum_result=int(num1)+int(num2)
print("The total is:",sum_result)
# Out:
# enter first number:- 24
# enter your second number:- 84
# The total is: 108
