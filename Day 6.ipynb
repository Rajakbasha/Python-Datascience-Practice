# %% [markdown]
# # Even or Odd

# %% [markdown]
# # description
# # Given an integer,print whether it is even or odd

# %%
num=int(input())
if num%2==0:
    print("Even number ")
else:
    print("Odd number ")
# Out:
#  10
# Even number

# %%
num=int(input())
if num%2==0:
    print("Even number ")
else:
    print("Odd number ")
# Out:
#  23
# Odd number

# %%
number=int(input())
if number%2==0:
    print("This is even number:-")
else:
    print("This is odd number :-")
# Out:
#  32
# This is even number:-

# %%
num=int(input("enter your number:-"))
if num%2==0:
    print("this is even number",num)
else:
    print("this is odd number:-",num)
# Out:
# enter your number:- 234567890265740
# this is even number 234567890265740

# %%
num=int(input("enter your number"))
if num%2==0:
        print("This is a even number")
else:
        print("this is a odd number is :-",num)
# Out:
# enter your number 90876543
# this is a odd number is :- 90876543

# %% [markdown]
# # Alarm Clock
# # Description :-

# %%
""" Trying to automate alarm clock by writing a function for it . given a day of the wek encoded as 1=Mon,2=Tue,.... 6=Sat, 7=Sun, And whether you are on vacation as a boolean value based on the way and whether you're on vaction write a function tht returns a time in form of a string indicating when the alarm clock should ring 
when not on a vaction on weekdays the alarm should ring at "7:00" aand on the weekends (Saturday and sunday ) it should ring ar"10:00"
while on weekdays the alarm should ring at" 10:00" on weekdays on vacation it should not ring on weekdays that is it should be return off """
# Out:
# ' Trying to automate alarm clock by writing a function for it . given a day of the wek encoded as 1=Mon,2=Tue,.... 6=Sat, 7=Sun, And whether you are on vacation as a boolean value based on the way and whether you\'re on vaction write a function tht returns a time in form of a string indicating when the alarm clock should ring \nwhen not on a vaction on weekdays the alarm should ring at "7:00" aand on the weekends (Saturday and sunday ) it should ring ar"10:00"\nwhile on weekdays the alarm should ring at" 10:00" on weekdays on vacation it should not ring on weekdays that is it should be return off '
